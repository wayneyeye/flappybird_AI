# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from time import sleep
from IPython.display import clear_output
# %matplotlib inline

# %%
csv_path="temp_log/dqn_4_engineered_05.csv"
try:
    df=pd.read_csv(csv_path)
except:
    print("error reading csv, try later...")
df.columns

plt.subplot(2,2,1)
plt.plot(df['iter'],df['learning_rate'])
plt.subplot(2,2,2)
plt.plot(df['iter'],df['epsilon'])

plt.subplot(2,2,3)
# plt.plot(df['iter'],df['last_1_avg'])
plt.plot(df['iter'],df['last_10_avg'])
plt.plot(df['iter'],df['last_100_avg'])
plt.plot(df['iter'],df['max_score_log'])
plt.subplot(2,2,4)
plt.plot(df['iter'][df['iter']!=0],df['loss_train'][df['iter']!=0])

# %%
clear_output(wait=True)
plt.plot(df['last_100_avg'])
plt.plot(df[' max_score_log'])
plt.show()
sleep(60)

# %%
while True:
    csv_path="temp_log/dqn_4_engineered_05.csv"
    try:
        df=pd.read_csv(csv_path)
    except:
        print("error reading csv, try later...")
    df.columns

    plt.subplot(2,2,1)
    plt.plot(df['iter'],df['learning_rate'])
    plt.subplot(2,2,2)
    plt.plot(df['iter'],df['epsilon'])

    plt.subplot(2,2,3)
    plt.plot(df['iter'],df['last_1_avg'])
    plt.plot(df['iter'],df['last_10_avg'])
    plt.plot(df['iter'],df['last_100_avg'])
    plt.plot(df['iter'],df['max_score_log'])
    plt.subplot(2,2,4)
    plt.plot(df['iter'][df['iter']!=0],df['loss_train'][df['iter']!=0])

    clear_output(wait=True)
    plt.show()
#     sleep(5)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-a4efc700903b> in <module>()
#      22     clear_output(wait=True)
#      23     plt.show()
# ---> 24     sleep(5)
#      25
#
# KeyboardInterrupt:
